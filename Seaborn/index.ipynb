# %% [markdown]
# # Seaborn
# - It is a statistical plotting library
# - It has beautiful default styles
# - Its also designed to work very well with pandas dataframe object.
#
# ### Installation - pip install seaborn
#
# - to see detail or code of seaborn visit to site - github seaborn python

# %% [markdown]
# # Distribution Plot
#
# - this create a histogram
# - in this we have to pass the dataframe frame name and column name

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = sns.load_dataset('tips')
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.distplot(df['total_bill'])# distplot means distribution plot
# Out:
# C:\Users\anuku\AppData\Local\Temp\ipykernel_14408\3975512946.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['total_bill'])# distplot means distribution plot
# <AxesSubplot: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# # Jointplot
# #### in this there is an argument - kind

# %%
sns.jointplot(x='total_bill',y='tip',data=df)

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='hex')

# %%
sns.jointplot(x='total_bill',y='tip',data=df,kind='reg') # reg means regression a machine learning concept

# %% [markdown]
# # Pair plot

# %%
sns.pairplot(df)

# %%
sns.pairplot(df,hue='sex') # in hue we have to pass a categorical column means non numeric column

# %% [markdown]
# # Rugplot
# - it draws a dash on the graph

# %%
sns.rugplot(df['total_bill'])
# Out:
# <AxesSubplot: xlabel='total_bill'>

# %% [markdown]
# # kdeplot (Kernel density estimation)
# - it is represents in distplot

# %%
sns.kdeplot(df['total_bill'])
# Out:
# <AxesSubplot: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# # Categorical Plot
#
# - Categorical means non numeric column

# %%
sns.barplot(x='sex',y='total_bill',data=df)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='total_bill'>

# %%
import numpy as np

# %%
sns.barplot(x='sex',y='total_bill',data=df,estimator=np.std)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='total_bill'>

# %%
sns.countplot(x='sex',data=df)
# Out:
# <AxesSubplot: xlabel='sex', ylabel='count'>

# %%
sns.boxplot(x='day',y='total_bill',data=df)
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.boxplot(x='day',y='total_bill',data=df,hue='smoker')
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %% [markdown]
# ### violinplot is same as boxplot

# %%
sns.violinplot(x='day',y='total_bill',data=df)
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day',y='total_bill',data=df)
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day',y='total_bill',data=df,hue='sex')
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.stripplot(x='day',y='total_bill',data=df,hue='sex',jitter=True)
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.swarmplot(x='day',y='total_bill',data=df,color='red')
# Out:
# <AxesSubplot: xlabel='day', ylabel='total_bill'>

# %%
sns.jointplot(x=y_test,y=prediction,)
